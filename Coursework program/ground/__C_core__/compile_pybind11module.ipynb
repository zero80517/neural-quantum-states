# %%
import os
from google.colab import drive
drive.mount('/content/drive')

current_location = '/content/drive/My Drive/Coursework program/ground/__C_core__'

assert os.path.exists(current_location), current_location + ' is not exists'

os.chdir(current_location)
print('Current location:', os.getcwd())
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Current location: /content/drive/My Drive/Coursework program/ground/__C_core__

# %%
# !pip install pybind11
# !c++ -O3 -Wall -shared -std=c++17 -fPIC `python3 -m pybind11 --includes` src/random.h src/random.cpp src/nqs.h src/nqs.cpp src/ising_1d_symmetric.h src/ising_1d_symmetric.cpp src/v15_isotropic.h src/v15_isotropic.cpp src/heisenberg_1d_symmetric.h src/heisenberg_1d_symmetric.cpp src/metropolis_hastings.h src/metropolis_hastings.cpp pybind11module.cpp -o pybind11module`python3-config --extension-suffix` 
# !python3 test.py
# Out:
# Collecting pybind11
#   Downloading https://files.pythonhosted.org/packages/89/e3/d576f6f02bc75bacbc3d42494e8f1d063c95617d86648dba243c2cb3963e/pybind11-2.5.0-py2.py3-none-any.whl (296kB)
#      |████████████████████████████████| 296kB 3.4MB/s
# Installing collected packages: pybind11
# Successfully installed pybind11-2.5.0
# time = 3.1814491748809814
# {'sampler results': {'acceptance': 0.998535, 'energy error': 0.04757832629554465, 'energy mean': -20.07241315899894, 'nacceptance': 199707, 'taucorr': 0.5650729013963119}}
# time = 1.8323578834533691
# {'sampler results': {'acceptance': 0.9983466666666667, 'energy error': 13.711192470665944, 'energy mean': -2901.0299390457512, 'nacceptance': 149752, 'taucorr': 0.6167141366105714}}
# time = 1.6701173782348633
# {'sampler results': {'acceptance': 0.49922, 'energy error': 0.0934840010228622, 'energy mean': -22.076085107343854, 'nacceptance': 99844, 'taucorr': 0.532122468519508}}
